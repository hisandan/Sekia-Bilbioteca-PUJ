# %%
# !pip install dbfread
# Out:
# ...
#
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: python -m pip install --upgrade pip

# %%
from dbfread import DBF
import pandas as pd


dbf_file = DBF('datos/af_Colombia.dbf') 
af_Colombia_df = pd.DataFrame(dbf_file)

# %%
af_Colombia_df.head()
# Out:
#    NR                             AU  AUNR
# 0  n1       Acevedo Oquendo, Rogelio   1.0
# 1  n2            Diaz, Jorge-Aurelio   1.0
# 2  n2          Rojas-Claros, Armando   2.0
# 3  n3    Moreno Rivas, Alvaro Martin   1.0
# 4  n4  Esguerra Pardo, Nicolas Boris   1.0

# %%
datacol_path ='datos/DATACOL.txt'

# Open the file in read mode
with open(datacol_path, 'r') as file:
    # Read the contents of the file
    datacol = file.read()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
df.shape
# Out:
# (2643329, 3)

# %%
x ={}
if x:
  print(True)
